# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

import numpy as np
from tqdm import tqdm
import glob

# %%
from data import Frames, Audio, Gaze

# %%
frames = Frames()
# Out:
# 100%|██████████| 144/144 [00:00<00:00, 219.58it/s]

# %%
audio = Audio()
# Out:
# 48000

# %%
frames.raw.shape, audio.raw.shape
# Out:
# ((14351, 480, 720), (22905856,))

# %%
def return_spike_rates(path_to_spikes):
    
    return #(time, 7)

# %%
def get_aligned(ts, data):
    
    if data == frame_data:
        # Do this process
        
    elif data == gaze_data:
        # Do this process
        
    else:
        raise ValueError("Unknown data type")
    
    return aligned_data

def get_aligned(ts, data):
    data.rescale_time
    
    return aligned_data

aligned_frames = get_aligned(1/30, frames_data) # (14351, 480, 720)
aligned_gaze = get_aligned(1/30, gaze_data) # (2000000000) Sampels

np.corrcoef(aligned_frames, aligned_gaze)
# Out:
#   Cell In[6], line 6
#     elif data == gaze_data:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3
