# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

import numpy as np
from tqdm import tqdm
import glob

from data import Frames, Audio, Gaze

# %%
frames = Frames()
audio = Audio()
gaze = Gaze()
# Out:
# ...
# 100%|██████████| 29/29 [00:00<00:00, 122.18it/s]

# %%
frames.raw.shape, audio.raw.shape, gaze.raw.shape
# Out:
# ((14351, 480, 720), (22905856,), (239429, 58))

# %%
frames.duration, audio.duration, gaze.duration
# Out:
# (478.8116666666667, 477.2053125, 478.856)

# %%
frames.rescale(0.1).shape, audio.rescale(0.1).shape, gaze.rescale(0.1).shape,
# Out:
# ((4789, 480, 720), (4789,), (4789, 58))
