# %% [markdown]
# # Data Walthrough

# %% [markdown]
# Data for this project can be broadly categorized into two types:
# 1. Data from the movie itself
# 2. Data from the interpretation of the movie

# %% [markdown]
# ## Data from the movie
#
# There are vairous ways to extract different aspects of the movie. For example, you can extract the script, the audio, the video, and so on.
#
# We ...

# %%
from data.movie import Frames, Audio

# %% [markdown]
# ## Data from interpretation of the movie
#
# These types of data are more subjective and can include:
# - Arousal Ratings
# - Single Neuron Recordings
