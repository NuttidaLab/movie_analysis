# %%
import numpy as np, pandas as pd

# %%
from data import Movie

# %%
Movie().audio()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Movie().audio()
#
# File ~/Documents/movie_analysis/data/movie.py:25, in Movie.audio(self, path)
#      24 def audio(self, path="bin/movie/audio.wav"):
# ---> 25     if not os.path.exists(path): raise FileNotFoundError(f"Audio file not found at {path}")
#      26     return librosa.load(path, sr=None)
#
# FileNotFoundError: Audio file not found at bin/movie/audio.wav
