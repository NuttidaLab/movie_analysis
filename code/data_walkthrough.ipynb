# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

import numpy as np
from tqdm import tqdm
import glob

from data import Frames, Audio, Gaze, Spike

# %%
frames = Frames()
audio = Audio()
gaze = Gaze()
spike = Spike()
# Out:
# ...
# 100%|██████████| 29/29 [00:00<00:00, 118.37it/s]

# %%
frames.raw.shape, audio.raw.shape, gaze.raw.shape, spike.raw.shape
# Out:
# ((14351, 480, 720), (22905856,), (239429, 58), (1597, 1457))

# %%
frames.duration, audio.duration, gaze.duration, spike.duration
# Out:
# (478.8116666666667, 477.2053125, 478.856, 478.79999999999995)

# %%
frames.rescale(0.1).shape, audio.rescale(0.1).shape, gaze.rescale(0.1).shape, spike.rescale(0.1).shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'base_start'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
gaze.rescale(0.1)
# Out:
#        x_P41CSR1  y_P41CSR1  x_P41CSR2  y_P41CSR2  x_P42CSR1  y_P42CSR1  \
# 0.0      313.750    262.500        NaN        NaN        NaN        NaN
# 0.1      313.750    265.000        NaN        NaN        NaN        NaN
# 0.2      312.500    257.500        NaN        NaN        NaN        NaN
# 0.3      311.250    260.625        NaN        NaN        NaN        NaN
# 0.4      306.250    238.125        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 478.4    102.500    303.125        NaN        NaN        NaN        NaN
# 478.5    101.875    301.250        NaN        NaN        NaN        NaN
# 478.6     77.500    320.000        NaN        NaN        NaN        NaN
# 478.7     77.500    316.250        NaN        NaN        NaN        NaN
# 478.8     78.125    315.625        NaN        NaN        NaN        NaN
#
#        x_P42CSR2  y_P42CSR2   x_P43CSR1   y_P43CSR1  ...   x_P57CSR2  \
# ...
